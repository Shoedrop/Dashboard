# %% [markdown]
# # Process Airbnb data

# %% [markdown]
# ## Import neccessary packages, modules and credentials

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from credentials import host, port, user, password, dbname_raw, dbname_processed, table_name

# %% [markdown]
# ## Ping Database to test connection

# %%
def ping_db(host, port, dbname, user, password):
    """
    Test connection to the PostgreSQL database
    """
    try:
        # Create a connection
        conn = psycopg2.connect(
            dbname=dbname,
            user=user,
            password=password,
            host=host,
            port=port
        )
        # Create a cursor object
        cur = conn.cursor()
        # Execute a simple query
        cur.execute("SELECT 1")
        # Close the cursor and connection
        cur.close()
        conn.close()
        print("Successfully connected to the database.")
    except Exception as e:
        print(f"Error connecting to the database: {e}")
        return False 

ping_db(host, port, dbname_raw, user, password)
# Out:
# Successfully connected to the database.

# %% [markdown]
# ## Fetch data and column names from the database

# %%
def fetch_data_and_columns(host, port, dbname, user, password, table_name):
    """
    Fetch data and column names from a PostgreSQL database
    """
    try:
        # Create a connection
        conn = psycopg2.connect(
            dbname=dbname,
            user=user,
            password=password,
            host=host,
            port=port
        )

        # Create a cursor object
        cur = conn.cursor()

        # Execute a query to fetch the data
        cur.execute(f"SELECT * FROM {table_name}")

        # Fetch the data
        rows = cur.fetchall()

        # Fetch the column names
        column_names = [desc[0] for desc in cur.description]

        # Close the cursor and connection
        cur.close()
        conn.close()

        return rows, column_names
    except Exception as e:
        print(f"Error fetching data from the database: {e}")
        return None, None

# Fetch the data and column names
rows, column_names = fetch_data_and_columns(host, port, dbname_raw, user, password, table_name)

# Create the DataFrame
df = pd.DataFrame(rows, columns=column_names)

# %% [markdown]
# ## Drop irrelevant columns

# %%
# These rows were deemed irrelevant for the analysis based on the data dictionary
columns_to_delete = ['scrape_id', 'host_thumbnail_url', 'host_picture_url', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'calendar_last_scraped', 'neighbourhood_group_cleansed', 'license']
filtered_df = df.drop(columns_to_delete, axis=1)

# %% [markdown]
# ## Check authenticity of each row

# %%
print(f"Number of rows with empty ID: {filtered_df['id'].isnull().sum()}")
print(f"Number of rows with empty URL: {filtered_df['listing_url'].isnull().sum()}")
print(f"Number of valid picture URLs: {filtered_df['picture_url'].str.startswith('https').value_counts()}")
# Out:
# Number of rows with empty ID: 0
# Number of rows with empty URL: 0
# Number of valid picture URLs: picture_url
# True    12495
# Name: count, dtype: int64

# %% [markdown]
# ## Format data

# %%
# Refer to the data dictionary and report to follow these data cleaning steps.
filtered_df['last_scraped'] = pd.to_datetime(filtered_df['last_scraped'])
filtered_df['description'] = filtered_df['description'].str.replace(r"[^a-zA-Z\d\_]+", " ")
filtered_df['host_since'] = pd.to_datetime(filtered_df['host_since'])
filtered_df['host_is_superhost'] = filtered_df['host_is_superhost'].fillna('f')
filtered_df['host_is_superhost'] = filtered_df['host_is_superhost'].map({'t': True, 'f': False}).astype('boolean')
filtered_df['bathrooms'] = filtered_df['bathrooms_text'].str.extract(r'^(\d+\.?\d*)')
filtered_df['price'] = filtered_df['price'].str.removeprefix('$').str.replace(',', '').astype(float)
filtered_df['maximum_nights'] = filtered_df['maximum_nights'].astype(int)
filtered_df['minimum_nights'] = filtered_df['minimum_nights'].astype(int)
filtered_df['number_of_reviews'] = filtered_df['number_of_reviews'].astype(int)
filtered_df['number_of_reviews_ltm'] = filtered_df['number_of_reviews_ltm'].astype(int)
filtered_df['number_of_reviews_l30d'] = filtered_df['number_of_reviews_l30d'].astype(int)
filtered_df['first_review'] = pd.to_datetime(filtered_df['first_review'])
filtered_df['last_review'] = pd.to_datetime(filtered_df['last_review'])
filtered_df['review_scores_rating'] = filtered_df['review_scores_rating'].astype(float).round(1)
filtered_df['review_scores_accuracy'] = filtered_df['review_scores_accuracy'].astype(float).round(1)
filtered_df['review_scores_cleanliness'] = filtered_df['review_scores_cleanliness'].astype(float).round(1)
filtered_df['review_scores_checkin'] = filtered_df['review_scores_checkin'].astype(float).round(1)
filtered_df['review_scores_communication'] = filtered_df['review_scores_communication'].astype(float).round(1)
filtered_df['review_scores_location'] = filtered_df['review_scores_location'].astype(float).round(1)
filtered_df['review_scores_value'] = filtered_df['review_scores_value'].astype(float).round(1)

# %% [markdown]
# ## Validate correct formatting

# %%
filtered_df.info()
filtered_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12495 entries, 0 to 12494
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            12495 non-null  int64
#  1   listing_url                                   12495 non-null  object
#  2   last_scraped                                  12495 non-null  datetime64[ns]
#  3   name                                          12495 non-null  object
#  4   description                                   12156 non-null  object
#  5   neighborhood_overview                         6461 non-null   object
#  6   picture_url                                   12495 non-null  object
#  7   host_id                                       12495 non-null  int64
#  8   host_url                                      12495 non-null  object
#  9   host_name                                     12494 non-null  object
#  10  host_since                                    12494 non-null  datetime64[ns]
#  11  host_location                                 12472 non-null  object
#  12  host_about                                    6400 non-null   object
#  13  host_response_time                            9658 non-null   object
#  14  host_response_rate                            9658 non-null   object
#  15  host_acceptance_rate                          10958 non-null  object
#  16  host_is_superhost                             12495 non-null  boolean
#  17  host_neighbourhood                            5391 non-null   object
#  18  host_listings_count                           12494 non-null  float64
#  19  host_total_listings_count                     12494 non-null  float64
#  20  host_verifications                            12494 non-null  object
#  21  host_has_profile_pic                          12494 non-null  object
#  22  host_identity_verified                        12494 non-null  object
#  23  neighbourhood                                 6461 non-null   object
#  24  neighbourhood_cleansed                        12495 non-null  object
#  25  latitude                                      12495 non-null  float64
#  26  longitude                                     12495 non-null  float64
#  27  property_type                                 12495 non-null  object
#  28  room_type                                     12495 non-null  object
#  29  accommodates                                  12495 non-null  int64
#  30  bathrooms                                     12416 non-null  object
#  31  bathrooms_text                                12483 non-null  object
#  32  bedrooms                                      12277 non-null  float64
#  33  beds                                          12330 non-null  float64
#  34  amenities                                     12495 non-null  object
#  35  price                                         12495 non-null  float64
#  36  minimum_nights                                12495 non-null  int64
#  37  maximum_nights                                12495 non-null  int64
#  38  has_availability                              12495 non-null  object
#  39  availability_30                               12495 non-null  int64
#  40  availability_60                               12495 non-null  int64
#  41  availability_90                               12495 non-null  int64
#  42  availability_365                              12495 non-null  int64
#  43  number_of_reviews                             12495 non-null  int64
#  44  number_of_reviews_ltm                         12495 non-null  int64
#  45  number_of_reviews_l30d                        12495 non-null  int64
#  46  first_review                                  10191 non-null  datetime64[ns]
#  47  last_review                                   10191 non-null  datetime64[ns]
#  48  review_scores_rating                          10191 non-null  float64
#  49  review_scores_accuracy                        10141 non-null  float64
#  50  review_scores_cleanliness                     10141 non-null  float64
#  51  review_scores_checkin                         10141 non-null  float64
#  52  review_scores_communication                   10141 non-null  float64
#  53  review_scores_location                        10140 non-null  float64
#  54  review_scores_value                           10141 non-null  float64
#  55  instant_bookable                              12495 non-null  object
#  56  calculated_host_listings_count                12495 non-null  int64
#  57  calculated_host_listings_count_entire_homes   12495 non-null  int64
#  58  calculated_host_listings_count_private_rooms  12495 non-null  int64
#  59  calculated_host_listings_count_shared_rooms   12495 non-null  int64
#  60  reviews_per_month                             10191 non-null  float64
#  61  API_Neighborhood                              12495 non-null  object
# dtypes: boolean(1), datetime64[ns](4), float64(15), int64(16), object(26)
# memory usage: 5.8+ MB
#        id                          listing_url last_scraped  \
# 0    6983    https://www.airbnb.com/rooms/6983   2022-06-25
# 1   26057   https://www.airbnb.com/rooms/26057   2022-06-25
# 2   26473   https://www.airbnb.com/rooms/26473   2022-06-25
# 3   29118   https://www.airbnb.com/rooms/29118   2022-06-25
# 4  130253  https://www.airbnb.com/rooms/130253   2022-06-25
#
#                                         name  \
# 0                       Copenhagen 'N Livin'
# 1        Lovely house - most attractive area
# 2  City Centre Townhouse Sleeps 1-10 persons
# 3            Best Location in Cool Istedgade
# 4            Lovely big room in Copenhagen Ø
#
#                                          description  \
# 0  Lovely apartment located in the hip Nørrebro a...
# 1  Our lovely house in the center of the city is ...
# 2  GUESTHOUSE ON KNABROSTRÆDE - located in the ab...
# 3  <b>The space</b><br />The apartment is situate...
# 4  <b>The space</b><br />Big room (7x3,5 meters),...
#
#                                neighborhood_overview  \
# 0  Nice bars and cozy cafes just minutes away, ye...
# 1  The neighborhood is the most famous one and th...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/42044170/f63c...    16774
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   109777
# 2  https://a0.muscache.com/pictures/8e132ba0-b68c...   112210
# 3  https://a0.muscache.com/pictures/b83c7003-367a...   125230
# 4  https://a0.muscache.com/pictures/15048292/a6a0...   641583
#
#                                    host_url host_name  ...  \
# 0   https://www.airbnb.com/users/show/16774     Simon  ...
# 1  https://www.airbnb.com/users/show/109777      Kari  ...
# 2  https://www.airbnb.com/users/show/112210     Julia  ...
# 3  https://www.airbnb.com/users/show/125230      Nana  ...
# 4  https://www.airbnb.com/users/show/641583  Mathilde  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         4.9                    4.7                 4.7
# 1                         4.8                    4.9                 4.8
# 2                         4.7                    4.9                 4.6
# 3                         5.0                    4.8                 4.8
# 4                         4.9                    4.7                 4.6
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                f                              1
# 2                f                             11
# 3                f                              1
# 4                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           6
# 3                                           1
# 4                                           0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             5
# 3                                             0
# 4                                             2
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                           0               1.10
# 1                                           0               0.56
# 2                                           0               2.06
# 3                                           0               0.15
# 4                                           0               0.16
#
#    API_Neighborhood
# 0       København N
# 1       København Ø
# 2       København K
# 3       København V
# 4       København Ø
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Export data to processed database

# %%
try:
    # Create a SQLAlchemy engine
    engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{dbname_processed}')

    # Write the DataFrame to the database table
    filtered_df.to_sql(table_name, engine, if_exists='replace', index=False)

    # Confirm the data has been written to the raw database
    print("Data has been written to the processed database.")
except Exception as e:
    print(f"Error writing data to the database: {e}")
# Out:
# Data has been written to the processed database.
